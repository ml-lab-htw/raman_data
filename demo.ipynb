# %%
from raman_data import raman_data
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
# List available datasets and plot the first two spectra from each dataset
datasets = raman_data()

# Iterate through each dataset and plot the first two spectra
for dataset_name in datasets:
    print(f"Dataset: {dataset_name}")

    # Load the dataset
    dataset = raman_data(dataset_name)

    # Extract spectra and target labels
    spectra = dataset.data
    target = dataset.target

    # Plot the first two spectra
    plt.plot(spectra[0], label='Spectrum 1')
    plt.plot(spectra[1], label='Spectrum 2')
    plt.xlabel('Raman Shift')
    plt.ylabel('Intensity')
    plt.title(dataset_name)
    plt.legend()
    plt.show()
# Out:
# Dataset: codina/raman-spectroscopy-of-diabetes
# Downloading Kaggle dataset: codina/raman-spectroscopy-of-diabetes
# Dataset downloaded into /Users/koddenbrock/.cache/kagglehub/datasets/codina/raman-spectroscopy-of-diabetes/versions/8
# Dataset: sergioalejandrod/raman-spectroscopy
# Downloading Kaggle dataset: sergioalejandrod/raman-spectroscopy
# Dataset downloaded into /Users/koddenbrock/.cache/kagglehub/datasets/sergioalejandrod/raman-spectroscopy/versions/1
# Dataset: andriitrelin/cells-raman-spectra
# Downloading Kaggle dataset: andriitrelin/cells-raman-spectra
# Dataset downloaded into /Users/koddenbrock/.cache/kagglehub/datasets/andriitrelin/cells-raman-spectra/versions/2
# Dataset: chlange/SubstrateMixRaman
# Downloading HuggingFace dataset: chlange/SubstrateMixRaman
# Dataset downloaded into ~/.cache/huggingface
# Dataset: MIND-Lab_covid+pd_ad_bundle
# Downloading dataset: MIND-Lab_covid+pd_ad_bundle
# MIND-Lab_covid+pd_ad_bundle.zip: 12.7MB [00:01, 7.65MB/s]
# Unzipping files...
# MIND-Lab_covid+pd_ad_bundle: 100%|██████████| 690/690 [00:00<00:00, 129kfiles/s]
# Dataset downloaded into /Users/koddenbrock/.cache/ziploader/MIND-Lab_covid+pd_ad_bundle
# Dataset: csho33_bacteria_id
# Downloading dataset: csho33_bacteria_id
# csho33_bacteria_id.zip: 100%|██████████| 629M/629M [00:43<00:00, 14.4MB/s]
# Unzipping files...
# csho33_bacteria_id: 100%|██████████| 12.0/12.0 [00:00<00:00, 15.4kfiles/s]
# Dataset downloaded into /Users/koddenbrock/.cache/ziploader/csho33_bacteria_id
# Dataset: mendeley_surface-enhanced-raman
# Downloading dataset: mendeley_surface-enhanced-raman
# mendeley_surface-enhanced-raman.zip: 100%|██████████| 256k/256k [00:00<00:00, 2.11MB/s]
# Unzipping files...
# mendeley_surface-enhanced-raman: 100%|██████████| 22.0/22.0 [00:00<00:00, 33.1kfiles/s]
# Dataset downloaded into /Users/koddenbrock/.cache/ziploader/mendeley_surface-enhanced-raman
# Dataset: dtu_raman-spectrum-matching
# Downloading dataset: dtu_raman-spectrum-matching
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[2], line 9
#       6 print(f"Dataset: {dataset_name}")
#       8 # Load the dataset
# ----> 9 dataset = raman_data(dataset_name)
#      11 # Extract spectra and target labels
#      12 spectra = dataset.data
#
# File ~/Repository/raman_data/raman_data/__init__.py:37, in raman_data(dataset_name, file_name, cache_dir, task_type)
#      35     return datasets.list_datasets(task_type=task_type)
#      36 else:
# ---> 37     return datasets.load_dataset(dataset_name=dataset_name,
#      38                                  file_name=file_name,
#      39                                  cache_dir=cache_dir)
#
# File ~/Repository/raman_data/raman_data/datasets.py:102, in load_dataset(dataset_name, file_name, cache_dir)
#      99     get_dataset = loader.load_dataset if file_name else loader.download_dataset
#     100     break
# --> 102 raman_data = get_dataset(dataset_name, file_name, cache_dir)
#     104 return RamanDataset(
#     105     data=raman_data,
#     106     target=raman_target,
#     107     metadata=raman_meta
#     108 )
#
# File ~/Repository/raman_data/raman_data/loaders/ZipLoader.py:88, in ZipLoader.download_dataset(dataset_name, file_name, cache_path)
#      85 print(f"Downloading dataset: {dataset_name}")
#      87 dataset_link = [link for link in ZipLoader.__LINKS if link.name == dataset_name][0]
# ---> 88 download_zip_path = LoaderTools.download(
#      89     url=dataset_link.url,
#      90     out_dir_path=cache_path,
#      91     out_file_name=dataset_name,
#      92     hash_target=dataset_link.checksum,
#      93     hash_type=dataset_link.checksum_type
#      94 )
#      96 print("Unzipping files...")
#      98 download_path = LoaderTools.extract_zip_file_content(
#      99     zip_file_path=download_zip_path,
#     100     unzip_target_subdir=dataset_name
#     101 )
#
# File ~/Repository/raman_data/raman_data/loaders/LoaderTools.py:202, in LoaderTools.download(url, out_dir_path, out_file_name, hash_target, hash_type)
#     195 total_size = (
#     196     int(response.headers["Content-Length"])
#     197     if "Content-Length" in response.headers
#     198     else None
#     199 )
#     201 # open/create file to write the data to
# --> 202 with open(out_file_path, "xb") as file:
#     203     # displays a loading bar in the cli
#     204     with tqdm(
#     205         total=total_size,
#     206         unit="B",
#    (...)    209     ) as pbar:
#     210         # writes chunks with predefined size into the file
#     211         for chunk in response.iter_content(CHUNK_SIZE):
#
# FileExistsError: [Errno 17] File exists: '/Users/koddenbrock/.cache/ziploader/dtu_raman-spectrum-matching.zip'
