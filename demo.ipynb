# %%
from raman_data import raman_data
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# List available datasets and plot the first two spectra from each dataset
datasets = raman_data()

datasets
# Out:
# ['codina/diabetes/AGEs',
#  'codina/diabetes/earLobe',
#  'codina/diabetes/innerArm',
#  'codina/diabetes/thumbNail',
#  'codina/diabetes/vein',
#  'sergioalejandrod/AminoAcids/glycine',
#  'sergioalejandrod/AminoAcids/leucine',
#  'sergioalejandrod/AminoAcids/phenylalanine',
#  'sergioalejandrod/AminoAcids/tryptophan',
#  'chlange/SubstrateMixRaman',
#  'chlange/RamanSpectraEcoliFermentation',
#  'sugar mixtures',
#  'Wheat lines',
#  'Adenine']

# %%
# Iterate through each dataset and plot the first two spectra
for dataset_name in datasets:
    print(f"Dataset: {dataset_name}")

    # Load the dataset
    dataset = raman_data(dataset_name)

    # Extract spectra and target labels
    spectra = dataset.data
    target = dataset.target

    # Plot the first two spectra
    plt.plot(spectra, label='Spectrum 1')
    #plt.plot(spectra[1], label='Spectrum 2')
    plt.xlabel('Raman Shift')
    plt.ylabel('Intensity')
    plt.title(dataset_name)
    #plt.legend()
    plt.show()
# Out:
# Dataset: codina/diabetes/AGEs
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: codina/diabetes/earLobe
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: codina/diabetes/innerArm
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: codina/diabetes/thumbNail
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: codina/diabetes/vein
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: sergioalejandrod/AminoAcids/glycine
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: sergioalejandrod/AminoAcids/leucine
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: sergioalejandrod/AminoAcids/phenylalanine
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: sergioalejandrod/AminoAcids/tryptophan
# Loading Kaggle dataset from default folder (~/.cache/kagglehub)
# Dataset: chlange/SubstrateMixRaman
# Loading HuggingFace dataset from default folder (~/.cache/huggingface)
# Dataset: chlange/RamanSpectraEcoliFermentation
# Loading HuggingFace dataset from default folder (~/.cache/huggingface)
# Dataset: sugar mixtures
# Raw data: 100%|██████████| 10.3k/10.3k [00:22<00:00, 456files/s]
# Dataset: Wheat lines
# Downloading file 7644521.zip: 694MB [02:22, 4.86MB/s]
# 7644521: 100%|██████████| 4.00/4.00 [00:00<00:00, 7.96files/s]
# Dataset: Adenine
